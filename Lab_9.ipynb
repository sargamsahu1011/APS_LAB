# %% [markdown]
# <a href="https://colab.research.google.com/github/sargamsahu1011/APS_LAB/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):
    d= {}
    v= []
    for node in graph:
        d[node] = float('inf')

    d[start] = 0

    while len(v) < len(graph):

        min_node = None
        min_d = float('inf')

        for node in graph:
            if node not in v and d[node] < min_d:
                min_d = d[node]
                min_node = node

        v.append(min_node)

        for n, w in graph[min_node].items():
            new_d = d[min_node]+w

            if new_distance < d[n]:
                d[n] = new_d

    return d

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph, start):
    d = {}
    v = []
    p = {}
    for n in graph:
        d[n] = float('inf')
        p[n] = None

    d[start] = 0

    while len(v) < len(graph):

        min_node = None
        min_d = float('inf')

        for n in graph:
            if n not in v and d[n] < min_d:
                mind = d[n]
                minnode = n

        if minnode is None:
            break

        v.append(minnode)

        for n, w in graph[minnode].items():
            newd = d[minnode] + w

            if newd < d[n]:
                d[n] = newd
                p[n] = minnode

    return d, p


#shortest path
def showpath(p, start, node):
    path = []
    while node is not None:
        path.append(node)
        node = p[node]

    path.reverse()
    return " -> ".join(path)

graph = {}

n = int(input("Enter number of nodes: "))

for i in range(n):
    node = input("Enter node name: ")
    graph[node] = {}

m = int(input("Enter number of edges: "))

for i in range(m):
    u = input("From node: ")
    v = input("To node: ")
    w = int(input("Weight: "))

    graph[u][v] = w
    graph[v][u] = w

source = input("source node: ")

dist,p = dijkstra(graph, source)

print("Shortest Distance", source)

for node in graph:
    print("To", node)
    print("Distance =", dist[node])
    print("Path =", showpath(p, source, node))
    print()
# Out:
# Enter number of nodes: 5
# Enter node name: A
# Enter node name: B
# Enter node name: C
# Enter node name: D
# Enter node name: E
# Enter number of edges: 6
# From node: A
# To node: B
# Weight: 4
# From node: C
# To node: D
# Weight: 3
# From node: E
# To node: A
# Weight: 9
# From node: B
# To node: C
# Weight: 2
# From node: A
# To node: C
# Weight: 3
# From node: C
# To node: B
# Weight: 1
# source node: A
# Shortest Distance A
# To A
# Distance = 0
# Path = A
#
# To B
# Distance = 4
# Path = A -> B
#
# To C
# Distance = 3
# Path = A -> C
#
# To D
# Distance = 6
# Path = A -> C -> D
#
# To E
# Distance = 9
# Path = A -> E
